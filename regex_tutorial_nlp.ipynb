# %%
chat1 = 'codebasics: you ask lot of questions 😠  1235678912, abc@xyz.com,9998887776665'
chat2 = 'codebasics: here it is: (123)-567-8912, abc@xyz.com'
chat3 = 'codebasics: yes, phone: 1235678912 email: abc@xyz.com'

# %%
import re

# %%
import re


pattern1 = r'\d{10}|\(\d{3}\)-\d{3}-\d{4}'
matches1 =re.findall(pattern1,chat1)
print(matches1)

matches2 =re.findall(pattern1,chat2)
print(matches2)

matches3 =re.findall(pattern1,chat3)
print(matches3)
# Out:
# ['1235678912', '9998887776']
# ['(123)-567-8912']
# ['1235678912']

# %%
import re

chat4 = 'codebasics: you ask lot of questions 😠  1235678912, abc@xyz.com,9998887776665'
chat5 = 'codebasics: here it is: (123)-567-8912,  abX_82@xyz.com.com'
chat6 = 'codebasics: yes, phone: 1235678912 email: abc@xyz.io'

pattern2 = r'[a-z0-9A-Z_]*@[a-z0-9A-Z]*\.[a-zA-Z]*'
matches4=re.findall(pattern2,chat4)
print(matches4)

matches5 =re.findall(pattern2,chat5)
print(matches5)

matches6 =re.findall(pattern2,chat6)
print(matches6)
# Out:
# ['abc@xyz.com']
# ['abX_82@xyz.com']
# ['abc@xyz.io']

# %%
chat7='codebasics: Hello, I am having an issue with my order # 4128899'
chat8='codebasics: I have a problem with my order number 412889912'
chat9='codebasics: My order 4128899123 is having an issue, I was charged 300$ when online it says 280$'
pattern3 =r'order[^\d]*(\d*)'
matches7 = re.findall(pattern3,chat7)
print(matches7)

matches8 = re.findall(pattern3,chat8)
print(matches8)

matches9 = re.findall(pattern3,chat9)
print(matches9)
# Out:
# ['4128899']
# ['412889912']
# ['4128899123']

# %%
text='''
Born	Elon Reeve Musk
June 28, 1971 (age 50)
Pretoria, Transvaal, South Africa
Citizenship	
South Africa (1971–present)
Canada (1971–present)
United States (2002–present)
Education	University of Pennsylvania (BS, BA)
Title	
Founder, CEO and Chief Engineer of SpaceX
CEO and product architect of Tesla, Inc.
Founder of The Boring Company and X.com (now part of PayPal)
Co-founder of Neuralink, OpenAI, and Zip2
Spouse(s)	
Justine Wilson
​
​(m. 2000; div. 2008)​
Talulah Riley
​
​(m. 2010; div. 2012)​
​
​(m. 2013; div. 2016)
'''

# %%
pattern10 = r'age (\d*)'
matches10 = re.findall(pattern10,text)
matches10
# Out:
# ['50']

# %%
pattern11 =r'Born(.*)'
matches11 =re.findall(pattern11,text)
matches11[0].strip()
# Out:
# 'Elon Reeve Musk'

# %%
pattern12 =r'Born.*\n(.*)\(age'
matches12 =re.findall(pattern12,text)
matches12[0].strip()
# Out:
# 'June 28, 1971'

# %%
pattern13 =r'\(age.*\n(.*)'
matches13 =re.findall(pattern13,text)
matches13
# Out:
# ['Pretoria, Transvaal, South Africa']

# %%
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\('
# <>:5: SyntaxWarning: invalid escape sequence '\('
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\('
# <>:5: SyntaxWarning: invalid escape sequence '\('
# C:\Users\Md. Abul Basher\AppData\Local\Temp\ipykernel_2912\3783779278.py:2: SyntaxWarning: invalid escape sequence '\d'
#   age = get_pattern_match('age (\d+)', text)
# C:\Users\Md. Abul Basher\AppData\Local\Temp\ipykernel_2912\3783779278.py:4: SyntaxWarning: invalid escape sequence '\('
#   birth_date = get_pattern_match('Born.*\n(.*)\(age', text)
# C:\Users\Md. Abul Basher\AppData\Local\Temp\ipykernel_2912\3783779278.py:5: SyntaxWarning: invalid escape sequence '\('
#   birth_place = get_pattern_match('\(age.*\n(.*)', text)

# %%
extract_personal_information(text)
# Out:
# C:\Users\Md. Abul Basher\AppData\Local\Temp\ipykernel_2912\3783779278.py:2: SyntaxWarning: invalid escape sequence '\d'
#   age = get_pattern_match('age (\d+)', text)
# C:\Users\Md. Abul Basher\AppData\Local\Temp\ipykernel_2912\3783779278.py:4: SyntaxWarning: invalid escape sequence '\('
#   birth_date = get_pattern_match('Born.*\n(.*)\(age', text)
# C:\Users\Md. Abul Basher\AppData\Local\Temp\ipykernel_2912\3783779278.py:5: SyntaxWarning: invalid escape sequence '\('
#   birth_place = get_pattern_match('\(age.*\n(.*)', text)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 extract_personal_information(text)
#
# Cell In[59], line 2, in extract_personal_information(text)
#       1 def extract_personal_information(text):
# ----> 2     age = get_pattern_match('age (\d+)', text)
#       3     full_name = get_pattern_match('Born(.*)\n', text)
# ...
